# %% [markdown]
# # CIPHERBYTE TECHNOLOGIES INTERN - TASK 2

# %% [markdown]
# # MASTERMIND GAME

# %%
import random

def generate_secret_number(n):
    """Generate a random n-digit secret number."""
    return ''.join(random.choice('0123456789') for _ in range(n))

def get_guess(prompt, n):
    """Get a valid n-digit guess from the player."""
    while True:
        guess = input(prompt)
        if guess.isdigit() and len(guess) == n:
            return guess
        else:
            print(f"Invalid guess. Please enter a {n}-digit number.")

def evaluate_guess(secret, guess):
    """Evaluate the guess and return a hint."""
    hint = ''
    for i in range(len(secret)):
        if secret[i] == guess[i]:
            hint += 'O'  # Digit is correct and in the right position
        elif guess[i] in secret:
            hint += 'X'  # Digit is correct but in the wrong position
        else:
            hint += '-'  # Digit is not in the secret number
    return hint

def play_mastermind(n):
    print("Let's play Mastermind!")
    print(f"Player 1 will set a {n}-digit secret number, and Player 2 will guess.")
    
    # Player 1 sets the secret number
    secret_number = generate_secret_number(n)
    attempts_p2 = 0
    
    while True:
        attempts_p2 += 1
        guess_p2 = get_guess(f"Player 2, enter your {n}-digit guess: ", n)
        
        if guess_p2 == secret_number:
            print(f"Congratulations, Player 2! You guessed the number {secret_number} correctly in {attempts_p2} attempts.")
            break
        
        hint = evaluate_guess(secret_number, guess_p2)
        print(f"Hint: {hint}")
    
    print("\nNow, Player 2 will set the secret number, and Player 1 will guess.")
    
    # Player 2 sets the secret number
    secret_number = generate_secret_number(n)
    attempts_p1 = 0
    
    while True:
        attempts_p1 += 1
        guess_p1 = get_guess(f"Player 1, enter your {n}-digit guess: ", n)
        
        if guess_p1 == secret_number:
            print(f"Congratulations, Player 1! You guessed the number {secret_number} correctly in {attempts_p1} attempts.")
            break
        
        hint = evaluate_guess(secret_number, guess_p1)
        print(f"Hint: {hint}")
    
    # Determine the winner
    if attempts_p1 < attempts_p2:
        print("\nPlayer 1 is crowned Mastermind! Guessed the number in fewer attempts.")
    elif attempts_p1 > attempts_p2:
        print("\nPlayer 2 is crowned Mastermind! Guessed the number in fewer attempts.")
    else:
        print("\nIt's a tie! Both players guessed the number in the same number of attempts.")

if __name__ == "__main__":
    n = 4  # You can change the number of digits for the secret number if desired
    play_mastermind(n)
# Out:
# Let's play Mastermind!
# Player 1 will set a 4-digit secret number, and Player 2 will guess.
# Player 2, enter your 4-digit guess: 1234
# Hint: -OX-
# Player 2, enter your 4-digit guess: 5238
# Hint: -OX-
# Player 2, enter your 4-digit guess: 5678
# Hint: --O-
# Player 2, enter your 4-digit guess: 8907
# Hint: ---X
# Player 2, enter your 4-digit guess: 1237
# Hint: -OXX
# Player 2, enter your 4-digit guess: 5237
# Hint: -OXX
# Player 2, enter your 4-digit guess: 4237
# Hint: -OXX
# Player 2, enter your 4-digit guess: 6237
# Hint: -OXX
# Player 2, enter your 4-digit guess: 0237
# Hint: -OXX
# Player 2, enter your 4-digit guess: 2237
# Hint: XOXX
# Player 2, enter your 4-digit guess: 1234
# Hint: -OX-
# Player 2, enter your 4-digit guess: 5648
# Hint: ----
# Player 2, enter your 4-digit guess: 5678
# Hint: --O-
# Player 2, enter your 4-digit guess: 4257
# Hint: -O-X
# Player 2, enter your 4-digit guess: 3275
# Hint: XOO-
# Player 2, enter your 4-digit guess: 1273
# Hint: -OOO
# Player 2, enter your 4-digit guess: 2273
# Hint: XOOO
# Player 2, enter your 4-digit guess: 3273
# Hint: XOOO
# Player 2, enter your 4-digit guess: 4273
# Hint: -OOO
# Player 2, enter your 4-digit guess: 5273
# Hint: -OOO
# Player 2, enter your 4-digit guess: 6273
# Hint: -OOO
# Player 2, enter your 4-digit guess: 7273
# Congratulations, Player 2! You guessed the number 7273 correctly in 22 attempts.
#
# Now, Player 2 will set the secret number, and Player 1 will guess.
# Player 1, enter your 4-digit guess: 1234
# Hint: ----
# Player 1, enter your 4-digit guess: 2345
# Hint: ----
# Player 1, enter your 4-digit guess: 6757
# Hint: XX-O
# Player 1, enter your 4-digit guess: 7467
# Hint: X-XO
# Player 1, enter your 4-digit guess: 6177
# Hint: X-XO
# Player 1, enter your 4-digit guess: 7777
# Hint: XXXO
# Player 1, enter your 4-digit guess: 9867
# Hint: -XXO
# Player 1, enter your 4-digit guess: 2345
# Hint: ----
# Player 1, enter your 4-digit guess: 34567
# Invalid guess. Please enter a 4-digit number.
# Player 1, enter your 4-digit guess: 3457
# Hint: ---O
# Player 1, enter your 4-digit guess: 4567
# Hint: --XO
# Player 1, enter your 4-digit guess: 5687
# Hint: -OOO
# Player 1, enter your 4-digit guess: 0687
# Hint: -OOO
# Player 1, enter your 4-digit guess: 9687
# Hint: -OOO
# Player 1, enter your 4-digit guess: 1687
# Hint: -OOO
# Player 1, enter your 4-digit guess: 6687
# Hint: XOOO
# Player 1, enter your 4-digit guess: 7687
# Hint: XOOO
# Player 1, enter your 4-digit guess: 8687
# Congratulations, Player 1! You guessed the number 8687 correctly in 17 attempts.
#
# Player 1 is crowned Mastermind! Guessed the number in fewer attempts.
